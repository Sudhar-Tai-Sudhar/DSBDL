# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 df = pd.read_csv('HousingData.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.shape
# Out:
# (506, 14)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.size
# Out:
# 7084

# %%
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.describe().T
# Out:
#          count        mean         std        min         25%         50%  \
# CRIM     486.0    3.611874    8.720192    0.00632    0.081900    0.253715
# ZN       486.0   11.211934   23.388876    0.00000    0.000000    0.000000
# INDUS    486.0   11.083992    6.835896    0.46000    5.190000    9.690000
# CHAS     486.0    0.069959    0.255340    0.00000    0.000000    0.000000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.538000
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.208500
# AGE      486.0   68.518519   27.999513    2.90000   45.175000   76.800000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.207450
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.000000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.000000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.050000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.440000
# ...

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df['CRIM'].fillna(value=df['CRIM'].mean(),inplace=True)
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_8520\3521608828.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CRIM'].fillna(value=df['CRIM'].mean(),inplace=True)

# %%
col_mis_val = ['ZN', 'INDUS', 'CHAS', 'AGE', 'LSTAT']
df[col_mis_val] = df[col_mis_val].fillna(df[col_mis_val].mean())

# %%
def detect_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] < lower_bound) | (data[column] > upper_bound)]


numerical_columns = ['CRIM', 'ZN', 'INDUS', 'AGE', 'LSTAT', 'MEDV']

for col in numerical_columns:
    outliers = detect_outliers(df, col)
    print(f"{col} has {len(outliers)} outliers")


for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
# Out:
# CRIM has 64 outliers
# ZN has 68 outliers
# INDUS has 0 outliers
# AGE has 0 outliers
# LSTAT has 12 outliers
# MEDV has 40 outliers

# %%
plt.figure(figsize=(12, 8))


for i, col in enumerate(numerical_columns, 1):
    plt.subplot(2, 3, i)  # Create a subplot (2 rows, 3 columns)
    sns.boxplot(data=df[col], color='skyblue')
    plt.title(f'Boxplot for {col}')
    plt.xlabel(col)


plt.tight_layout()
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
corr = df.corr() #Function to find the correlation
print(corr)
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.213438  0.514039 -0.004140  0.593302 -0.068086  0.355975
# ZN      -0.213438  1.000000 -0.402101  0.021961 -0.389614  0.257140 -0.378744
# INDUS    0.514039 -0.402101  1.000000  0.044762  0.686995 -0.255336  0.503604
# CHAS    -0.004140  0.021961  0.044762  1.000000  0.103067  0.070594  0.092526
# NOX      0.593302 -0.389614  0.686995  0.103067  1.000000 -0.212566  0.619069
# RM      -0.068086  0.257140 -0.255336  0.070594 -0.212566  1.000000 -0.129745
# AGE      0.355975 -0.378744  0.503604  0.092526  0.619069 -0.129745  1.000000
# DIS     -0.415613  0.493217 -0.637988 -0.100823 -0.718989  0.137478 -0.639176
# RAD      0.874844 -0.192884  0.480636  0.008197  0.511475 -0.005367  0.282144
# TAX      0.812416 -0.276761  0.645979 -0.039134  0.611383 -0.092253  0.383659
# PTRATIO  0.229404 -0.289467  0.197427 -0.151694  0.016294 -0.107477  0.133935
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['MEDV'])  # Features
y = df['MEDV']

# %%
from sklearn.preprocessing import StandardScaler

# Apply StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.33)

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 11.563139050266138

# %%
lr.coef_
# Out:
# array([-0.33525298,  0.03544604,  0.02468542,  1.30388039, -5.83755868,
#         4.37390127, -0.02010991, -0.52298615,  0.22279939, -0.00910728,
#        -0.60873639,  0.01471701, -0.27379089])

# %%
prediction = lr.predict(X_test) #To predict the target values
print(prediction)
# Out:
# [22.82978814 22.08408456 26.69674416 24.24935696 15.72689036 22.74061464
#  25.40507343 23.6359786  25.68641137 15.92037874 20.59016186 18.28996513
#  26.07534308 15.13968888 19.1435509  19.7360982  18.71589708 22.80871661
#  19.03002088 21.6596748  17.72089819 18.07484638 21.04774737 19.23095082
#  29.76318328 21.20254435 21.76712123 20.94181228 14.55165292 20.77327659
#  10.96641498 34.45212946 16.44786568 21.58632845 23.91678323 22.7800189
#  27.63650602 24.61820302 27.42260271 23.51731406 18.72635123 26.31561784
#  15.74521222 14.70719779 29.72578123 21.79001628 20.29993414 19.05766391
#  15.07731839 21.0187137  13.24223728 19.4126177  17.08942126 15.73417385
#  19.60065269 24.38625624 26.38093653 24.89053904 27.71561868 17.02082919
#  16.40833731 21.88357901 20.06128246 27.82472507 21.69822418 27.15669076
#  23.79640705 21.35671231 19.66641952  9.83577416 24.34365877 21.08257214
#  28.6747755  31.80058    20.31957646 22.18601032 27.20599489 17.54059768
# ...

# %%
y_test
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,prediction)
# Out:
# 0.5744581949583139

# %%
mean_squared_error(y_test, prediction)
# Out:
# 12.13983539607828
